# %% [markdown]
# # Programming Assignment 1
# ## Wil Gaboury

# %%
# imports
import a_star
import pandas as pd
import plotnine as p9
import time

# %% [markdown]
# ## Part 1: Exploring Search Algorithm

# %% [markdown]
# ### 1. Randomly create a family of 30 TSP graphs/matrices for each size 5, 10, 15, 20, ...

# %%
def gen_graphs(n):
    result = []
    for i in range(30):
        result.append(a_star.TSPGraph.generate_random(n))
    return result

families = [
    (4, gen_graphs(4)),
    (6, gen_graphs(6)),
    (8, gen_graphs(8))
#     (10, gen_graphs(10)),
#     (12, gen_graphs(12))
]

# %% [markdown]
# ### 1. Run the above algorithms on each of the family of size 5, of size 10, etc....
# ### 2. For each family of 30 graphs/matrices you’ll compute the AVERAGE/MIN/MAX of totalcost, number of nodes, CPU and real-world runtime

# %%
df = pd.DataFrame(columns=['n', 'h', 'total_cost', 'node_count', 'cpu_time', 'real_time'])
hs = {
    'uniform_cost': a_star.h_uniform_cost,
    'random_edge': a_star.h_random_edge,
    'smallest_edge': a_star.h_smallest_edge
}

for graph_size, family in families:
    for h_name, h_func in hs.items():
        for graph in family:    
            start_cpu_time = time.process_time()
            start_real_time = time.time()

            search_result = a_star.a_star(graph.get_start_state_node(), a_star.is_goal, h_func)

            end_cpu_time = time.process_time()
            end_real_time = time.time()

            df = df.append({
                'n': graph_size,
                'h': h_name,
                'total_cost': sum(list(search_result[0].path)),
                'node_count': search_result[1], 
                'cpu_time': end_cpu_time - start_cpu_time,
                'real_time': end_real_time - start_real_time
            }, ignore_index=True)

# %%
df = df.astype({'total_cost': 'int64', 'node_count': 'int64'})
df_summary = df.groupby(['n', 'h']).agg(['mean', 'min', 'max'])
df_summary
# Out:
#                 total_cost           node_count             cpu_time  \
#                       mean min max         mean  min   max      mean
# n h
# 4 random_edge     4.766667   3   6    13.366667    5    29  0.000481
#   smallest_edge   4.766667   3   6    18.200000    8    29  0.000980
#   uniform_cost    4.766667   3   6    18.200000    8    29  0.000484
# 6 random_edge    11.566667   6  15    69.466667   18   208  0.004006
#   smallest_edge  12.200000   6  15   220.100000   55   601  0.023457
#   uniform_cost   12.200000   6  15   220.100000   55   601  0.005770
# 8 random_edge    23.066667  15  28   414.133333   58  1936  0.034703
#   smallest_edge  24.666667  16  28  2332.900000  263  5512  0.410481
#   uniform_cost   24.666667  16  28  2332.900000  263  5512  0.129116
#
#                                     real_time
#                       min       max      mean       min       max
# n h
# 4 random_edge    0.000205  0.000937  0.000481  0.000204  0.000936
#   smallest_edge  0.000506  0.001445  0.000981  0.000504  0.001443
#   uniform_cost   0.000204  0.001218  0.000484  0.000203  0.001212
# 6 random_edge    0.001137  0.011222  0.004012  0.001137  0.011234
#   smallest_edge  0.006166  0.057954  0.023484  0.006175  0.058022
#   uniform_cost   0.001432  0.015054  0.005779  0.001432  0.015070
# 8 random_edge    0.005231  0.154582  0.034740  0.005239  0.154743
#   smallest_edge  0.060003  1.035325  0.410815  0.060060  1.036651
#   uniform_cost   0.009490  0.676785  0.129259  0.009501  0.678136

# %%
# 
df_summary.columns = [
    'total_cost_mean', 
    'total_cost_min',
    'total_cost_max',
    'node_count_mean',
    'node_count_min',
    'node_count_max',
    'cpu_time_mean',
    'cpu_time_min',
    'cpu_time_max',
    'real_time_mean',
    'real_time_min',
    'real_time_max'
]
df_summary = df_summary.reset_index()

# %%
(
    p9.ggplot(df_summary, p9.aes(x='n', y='total_cost_mean', color='h'))
        + p9.geom_line(position=p9.position_dodge(width=0.075))
)
# Out:
# <ggplot: (8789626093300)>
